# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/preparedData/incidents.csv')

df = df.head(100)

dummies = pd.get_dummies(df, columns=['incident_classification'], dtype=int)

# df = df[['alarm_box_latitude', 'alarm_box_longtitude']]

df = df.merge(dummies)

sns.pairplot(df[['incident_travel_tm_seconds_qy', 'alarm_box_latitude', 'alarm_box_longtitude', 'alarm_box_borough']],hue='alarm_box_borough')
