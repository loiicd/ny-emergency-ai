# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/preparedData/incidents.csv')

df = df[['alarm_box_latitude', 'alarm_box_longtitude', 'alarm_box_borough']]

df = df.sample(n=50000)

df.head()
# Out:
#          alarm_box_latitude  alarm_box_longtitude alarm_box_borough
# 886801            40.696987            -73.935223          BROOKLYN
# 457821            40.610302            -73.959521          BROOKLYN
# 754406            40.706724            -74.006781         MANHATTAN
# 1644334           40.671254            -73.738149            QUEENS
# 1105235           40.685642            -73.764396            QUEENS

# %%
# df = pd.get_dummies(df, columns=['alarm_box_borough'], dtype=int)

df.head()
# Out:
#          alarm_box_latitude  alarm_box_longtitude alarm_box_borough
# 886801            40.696987            -73.935223          BROOKLYN
# 457821            40.610302            -73.959521          BROOKLYN
# 754406            40.706724            -74.006781         MANHATTAN
# 1644334           40.671254            -73.738149            QUEENS
# 1105235           40.685642            -73.764396            QUEENS

# %%
sns.pairplot(df, hue='alarm_box_borough', kind="kde")

# %%
# df = df.head(100)

# sns.pairplot(df, hue='incident_classification_group')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'incident_classification_group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 3
# ...
