# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/preparedData/incidents.csv')

df = df[['incident_travel_tm_seconds_qy', 'engines_assigned_quantity', 'ladders_assigned_quantity', 'other_units_assigned_quantity', 'alarm_box_borough']]

df = df.sample(n=50000)

df.head()
# Out:
#          incident_travel_tm_seconds_qy  engines_assigned_quantity  \
# 694496                           116.0                        1.0
# 1447571                          208.0                        1.0
# 1046760                          223.0                        1.0
# 40401                            324.0                        3.0
# 1307273                          234.0                        1.0
#
#          ladders_assigned_quantity  other_units_assigned_quantity  \
# 694496                         0.0                            0.0
# 1447571                        0.0                            0.0
# 1046760                        0.0                            0.0
# 40401                          2.0                            1.0
# 1307273                        0.0                            0.0
#
#         alarm_box_borough
# 694496           BROOKLYN
# 1447571             BRONX
# 1046760          BROOKLYN
# 40401           MANHATTAN
# 1307273            QUEENS

# %%
# df = pd.get_dummies(df, columns=['alarm_box_borough'], dtype=int)

df.head()
# Out:
#          incident_travel_tm_seconds_qy  engines_assigned_quantity  \
# 694496                           116.0                        1.0
# 1447571                          208.0                        1.0
# 1046760                          223.0                        1.0
# 40401                            324.0                        3.0
# 1307273                          234.0                        1.0
#
#          ladders_assigned_quantity  other_units_assigned_quantity  \
# 694496                         0.0                            0.0
# 1447571                        0.0                            0.0
# 1046760                        0.0                            0.0
# 40401                          2.0                            1.0
# 1307273                        0.0                            0.0
#
#         alarm_box_borough
# 694496           BROOKLYN
# 1447571             BRONX
# 1046760          BROOKLYN
# 40401           MANHATTAN
# 1307273            QUEENS

# %%
sns.pairplot(df, hue='alarm_box_borough')

# %%
# df = df.head(100)

# sns.pairplot(df, hue='incident_classification_group')
