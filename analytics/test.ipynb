# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/preparedData/incidents.csv')

df = df[['incident_travel_tm_seconds_qy', 'engines_assigned_quantity', 'alarm_box_borough']]

df = df.sample(n=500000)

df.head()
# Out:
#         incident_travel_tm_seconds_qy  engines_assigned_quantity  \
# 593923                          302.0                        0.0
# 568551                          587.0                        1.0
# 35760                            98.0                        0.0
# 535467                            0.0                        1.0
# 421958                          199.0                        1.0
#
#        alarm_box_borough
# 593923            QUEENS
# 568551            QUEENS
# 35760           BROOKLYN
# 535467          BROOKLYN
# 421958         MANHATTAN

# %%
sns.jointplot(data=df, x='incident_travel_tm_seconds_qy', y='engines_assigned_quantity')
