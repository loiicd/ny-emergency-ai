# %%
import pandas as pd

pd.set_option('display.max_columns', None)

fire_incidents = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/rawData/fire-incidents/fire-incidents.csv')

fire_incidents.head()
# Out:
# /var/folders/jc/4tg2kq2n5sl5q7m9gbm6g6h80000gn/T/ipykernel_14344/3291123784.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   fire_incidents = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/rawData/fire-incidents/fire-incidents.csv')
#   starfire_incident_id        incident_datetime alarm_box_borough  \
# 0     2100404460110002  2021-01-04T00:01:00.000         MANHATTAN
# 1     2100433250140001  2021-01-04T00:01:00.000          BROOKLYN
# 2     2100411280150003  2021-01-04T00:01:00.000            QUEENS
# 3     2100416590110004  2021-01-04T00:02:00.000         MANHATTAN
# 4     2100413490110006  2021-01-04T00:02:00.000         MANHATTAN
#
#    alarm_box_number     alarm_box_location incident_borough  zipcode  \
# 0               446   3 AVE & ST. MARKS PL        MANHATTAN  10003.0
# 1              3325     AVENUE O & E 13 ST         BROOKLYN  11230.0
# 2              1128  MOTT AVE & DICKENS ST           QUEENS  11691.0
# ...

# %%
import pandas as pd

ems_incidents = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/rawData/ems-incidents/ems-incident-dispatch-data.csv')

ems_incidents = ems_incidents.rename(columns={'INCIDENT_DATETIME': 'incident_datetime', 'ZIPCODE': 'zipcode', 'CITYCOUNCILDISTRICT': 'citycouncildistrict'})

ems_incidents.head()
# Out:
# /var/folders/jc/4tg2kq2n5sl5q7m9gbm6g6h80000gn/T/ipykernel_14344/3827941210.py:3: DtypeWarning: Columns (7,11,17,21,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   ems_incidents = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/rawData/ems-incidents/ems-incident-dispatch-data.csv')
#    CAD_INCIDENT_ID        incident_datetime INITIAL_CALL_TYPE  \
# 0        202134231  2020-07-31T23:59:51.000               UNC
# 1        202134230  2020-07-31T23:59:50.000               UNC
# 2        202134229  2020-07-31T23:59:27.000            MVAINJ
# 3        202134228  2020-07-31T23:58:54.000              SICK
# 4        202134226  2020-07-31T23:58:43.000               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            2             UNC                          2
# 1                            2             UNC                          2
# ...

# %%
df = pd.concat([fire_incidents, ems_incidents])

pd.concat

print(len(df))

df.head()
# Out:
# 31030425
#   starfire_incident_id        incident_datetime alarm_box_borough  \
# 0     2100404460110002  2021-01-04T00:01:00.000         MANHATTAN
# 1     2100433250140001  2021-01-04T00:01:00.000          BROOKLYN
# 2     2100411280150003  2021-01-04T00:01:00.000            QUEENS
# 3     2100416590110004  2021-01-04T00:02:00.000         MANHATTAN
# 4     2100413490110006  2021-01-04T00:02:00.000         MANHATTAN
#
#    alarm_box_number     alarm_box_location incident_borough  zipcode  \
# 0             446.0   3 AVE & ST. MARKS PL        MANHATTAN  10003.0
# 1            3325.0     AVENUE O & E 13 ST         BROOKLYN  11230.0
# 2            1128.0  MOTT AVE & DICKENS ST           QUEENS  11691.0
# 3            1659.0      BROADWAY & 153 ST        MANHATTAN  10031.0
# 4            1349.0         5 AVE & 112 ST        MANHATTAN  10026.0
#
#    policeprecinct  citycouncildistrict  communitydistrict  \
# 0             9.0                  2.0              103.0
# ...
