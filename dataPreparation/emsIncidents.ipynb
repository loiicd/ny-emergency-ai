# %% [markdown]
# ## Read Incidents Raw Data

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

df = pd.read_csv('/Users/loic.doerr/dev/ny-emergency-ai/rawData/ems-incidents/ems-incident-dispatch-data.csv', nrows=50000)

df.head()
# Out:
#    CAD_INCIDENT_ID        INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        202134231  2020-07-31T23:59:51.000               UNC
# 1        202134230  2020-07-31T23:59:50.000               UNC
# 2        202134229  2020-07-31T23:59:27.000            MVAINJ
# 3        202134228  2020-07-31T23:58:54.000              SICK
# 4        202134226  2020-07-31T23:58:43.000               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            2             UNC                          2
# 1                            2             UNC                          2
# 2                            4          MVAINJ                          4
# 3                            6            SICK                          6
# 4                            7            EDPC                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0   2020-08-01T00:00:19.000                              Y
# ...

# %%
import numpy as np

df['HOSP_TRANSPORT'] = df['FIRST_TO_HOSP_DATETIME'].notna()

df.head()
# Out:
#    CAD_INCIDENT_ID        INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        202134231  2020-07-31T23:59:51.000               UNC
# 1        202134230  2020-07-31T23:59:50.000               UNC
# 2        202134229  2020-07-31T23:59:27.000            MVAINJ
# 3        202134228  2020-07-31T23:58:54.000              SICK
# 4        202134226  2020-07-31T23:58:43.000               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            2             UNC                          2
# 1                            2             UNC                          2
# 2                            4          MVAINJ                          4
# 3                            6            SICK                          6
# 4                            7            EDPC                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0   2020-08-01T00:00:19.000                              Y
# ...

# %% [markdown]
# ## Add Timestamps

# %%
import numpy as np

# Incident
df['INCIDENT_DATETIME'] = pd.to_datetime(df['INCIDENT_DATETIME'], errors='coerce')
df['INCIDENT_TIMESTAMP'] = df['INCIDENT_DATETIME'].apply(lambda x: int(x.timestamp()) if pd.notnull(x) else None)
# df['INCIDENT_TIMESTAMP'] = df['INCIDENT_DATETIME'].astype('int', errors='ignore')
df['INCIDENT_TIMESTAMP'] = df['INCIDENT_TIMESTAMP'].div(10**9)

# # First Assignment
# df['FIRST_ASSIGNMENT_DATETIME'] = pd.to_datetime(df['FIRST_ASSIGNMENT_DATETIME'])
# df['FIRST_ASSIGNMENT_TIMESTAMP'] = df['FIRST_ASSIGNMENT_DATETIME'].astype(int) // 10**9

# # First Activation
# df['FIRST_ACTIVATION_DATETIME'] = pd.to_datetime(df['FIRST_ACTIVATION_DATETIME'])
# df['FIRST_ACTIVATION_TIMESTAMP'] = df['FIRST_ACTIVATION_DATETIME'].astype(int) // 10**9

# # First on Scene
# df['FIRST_ON_SCENE_DATETIME'] = pd.to_datetime(df['FIRST_ON_SCENE_DATETIME'])
# df['FIRST_ON_SCENE_TIMESTAMP'] = df['FIRST_ON_SCENE_DATETIME'].astype(int) // 10**9

# # First to Hospital
# df['FIRST_TO_HOSP_DATETIME'] = pd.to_datetime(df['FIRST_TO_HOSP_DATETIME'], errors='coerce')
# df['FIRST_TO_HOSP_TIMESTAMP'] = df['FIRST_TO_HOSP_DATETIME'].apply(lambda x: x.timestamp() if pd.notnull(x) else np.nan)
# # df['FIRST_TO_HOSP_TIMESTAMP'] = df['FIRST_TO_HOSP_TIMESTAMP'].div(10**9)

# # First Hospital Arrival
# df['FIRST_HOSP_ARRIVAL_DATETIME'] = pd.to_datetime(df['FIRST_HOSP_ARRIVAL_DATETIME'])
# df['FIRST_HOSP_ARRIVAL_TIMESTAMP'] = df['FIRST_HOSP_ARRIVAL_DATETIME'].astype(int) // 10**9

# # Incident Closed
# df['INCIDENT_CLOSE_DATETIME'] = pd.to_datetime(df['INCIDENT_CLOSE_DATETIME'])
# df['INCIDENT_CLOSE_TIMESTAMP'] = df['INCIDENT_CLOSE_DATETIME'].astype(int) // 10**9

df.head()
# Out:
#    CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        202134231 2020-07-31 23:59:51               UNC
# 1        202134230 2020-07-31 23:59:50               UNC
# 2        202134229 2020-07-31 23:59:27            MVAINJ
# 3        202134228 2020-07-31 23:58:54              SICK
# 4        202134226 2020-07-31 23:58:43               EDP
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            2             UNC                          2
# 1                            2             UNC                          2
# 2                            4          MVAINJ                          4
# 3                            6            SICK                          6
# 4                            7            EDPC                          7
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0   2020-08-01T00:00:19.000                              Y
# ...

# %%
df.to_csv('../preparedData/emsIncidents.csv', index=False)
